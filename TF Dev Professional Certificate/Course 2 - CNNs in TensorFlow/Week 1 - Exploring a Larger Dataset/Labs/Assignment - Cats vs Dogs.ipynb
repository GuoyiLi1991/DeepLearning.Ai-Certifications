# %%
# ATTENTION: Please do not alter any of the provided code in the exercise. Only add your own code where indicated
# ATTENTION: Please do not add or remove any cells in the exercise. The grader will check specific cells based on the cell position.
# ATTENTION: Please use the provided epoch values when training.

# In this exercise you will train a CNN on the FULL Cats-v-dogs dataset
# This will require you doing a lot of data preprocessing because
# the dataset isn't split into training and validation for you
# This code block has all the required inputs
import os
import zipfile
import random
import tensorflow as tf
import shutil
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from shutil import copyfile
from os import getcwd

# %%
path_cats_and_dogs = f"{getcwd()}/../tmp2/cats-and-dogs.zip"
shutil.rmtree('/tmp')

local_zip = path_cats_and_dogs
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

# %%
print(len(os.listdir('/tmp/PetImages/Cat/')))
print(len(os.listdir('/tmp/PetImages/Dog/')))

# Expected Output:
# 1500
# 1500
# Out:
# 1500
# 1500

# %%
# Use os.mkdir to create your directories
# You will need a directory for cats-v-dogs, and subdirectories for training
# and testing. These in turn will need subdirectories for 'cats' and 'dogs'
try:
    dir_to_create = [
        '/tmp/cats-v-dogs',
        '/tmp/cats-v-dogs/training',
        '/tmp/cats-v-dogs/testing',
        '/tmp/cats-v-dogs/training/cats',
        '/tmp/cats-v-dogs/training/dogs',
        '/tmp/cats-v-dogs/testing/cats',
        '/tmp/cats-v-dogs/testing/dogs'
    ]

    for directory in dir_to_create:
        try:
            os.mkdir(directory)
            print(directory, 'successfully created')
        except:
            print(directory, 'failed to create')
except OSError:
    pass
# Out:
# /tmp/cats-v-dogs successfully created
# /tmp/cats-v-dogs/training successfully created
# /tmp/cats-v-dogs/testing successfully created
# /tmp/cats-v-dogs/training/cats successfully created
# /tmp/cats-v-dogs/training/dogs successfully created
# /tmp/cats-v-dogs/testing/cats successfully created
# /tmp/cats-v-dogs/testing/dogs successfully created

# %%
# Write a python function called split_data which takes
# a SOURCE directory containing the files
# a TRAINING directory that a portion of the files will be copied to
# a TESTING directory that a portion of the files will be copie to
# a SPLIT SIZE to determine the portion
# The files should also be randomized, so that the training set is a random
# X% of the files, and the test set is the remaining files
# SO, for example, if SOURCE is PetImages/Cat, and SPLIT SIZE is .9
# Then 90% of the images in PetImages/Cat will be copied to the TRAINING dir
# and 10% of the images will be copied to the TESTING dir
# Also -- All images should be checked, and if they have a zero file length,
# they will not be copied over
#
# os.listdir(DIRECTORY) gives you a listing of the contents of that directory
# os.path.getsize(PATH) gives you the size of the file
# copyfile(source, destination) copies a file from source to destination
# random.sample(list, len(list)) shuffles a list
def split_data(SOURCE, TRAINING, TESTING, SPLIT_SIZE):
    files = []
    
    for file_name in os.listdir(SOURCE):
        file_path = SOURCE + file_name
        
        if os.path.getsize(file_path):
            files.append(file_name)
        else:
            print('{} has zero file length, will not be copied over'.format(file_name))
            
    split = int(len(files) * SPLIT_SIZE)
    
    shuffled = random.sample(files, len(files))
    
    training_set = shuffled[:split]
    testing_set = shuffled[split:]
    
    for file_name in training_set:
        print(SOURCE + file_name, TRAINING + file_name)
        copyfile(SOURCE + file_name, TRAINING + file_name)
        
    for file_name in testing_set:
        copyfile(SOURCE + file_name, TESTING + file_name)

CAT_SOURCE_DIR = "/tmp/PetImages/Cat/"
TRAINING_CATS_DIR = "/tmp/cats-v-dogs/training/cats/"
TESTING_CATS_DIR = "/tmp/cats-v-dogs/testing/cats/"
DOG_SOURCE_DIR = "/tmp/PetImages/Dog/"
TRAINING_DOGS_DIR = "/tmp/cats-v-dogs/training/dogs/"
TESTING_DOGS_DIR = "/tmp/cats-v-dogs/testing/dogs/"

split_size = .9
split_data(CAT_SOURCE_DIR, TRAINING_CATS_DIR, TESTING_CATS_DIR, split_size)
split_data(DOG_SOURCE_DIR, TRAINING_DOGS_DIR, TESTING_DOGS_DIR, split_size)
# Out:
# /tmp/PetImages/Cat/cat.992.jpg /tmp/cats-v-dogs/training/cats/cat.992.jpg
# /tmp/PetImages/Cat/cat.2045.jpg /tmp/cats-v-dogs/training/cats/cat.2045.jpg
# /tmp/PetImages/Cat/cat.850.jpg /tmp/cats-v-dogs/training/cats/cat.850.jpg
# /tmp/PetImages/Cat/cat.860.jpg /tmp/cats-v-dogs/training/cats/cat.860.jpg
# /tmp/PetImages/Cat/cat.2269.jpg /tmp/cats-v-dogs/training/cats/cat.2269.jpg
# /tmp/PetImages/Cat/cat.2041.jpg /tmp/cats-v-dogs/training/cats/cat.2041.jpg
# /tmp/PetImages/Cat/cat.2277.jpg /tmp/cats-v-dogs/training/cats/cat.2277.jpg
# /tmp/PetImages/Cat/cat.775.jpg /tmp/cats-v-dogs/training/cats/cat.775.jpg
# /tmp/PetImages/Cat/cat.2248.jpg /tmp/cats-v-dogs/training/cats/cat.2248.jpg
# /tmp/PetImages/Cat/cat.2022.jpg /tmp/cats-v-dogs/training/cats/cat.2022.jpg
# /tmp/PetImages/Cat/cat.71.jpg /tmp/cats-v-dogs/training/cats/cat.71.jpg
# /tmp/PetImages/Cat/cat.779.jpg /tmp/cats-v-dogs/training/cats/cat.779.jpg
# /tmp/PetImages/Cat/cat.705.jpg /tmp/cats-v-dogs/training/cats/cat.705.jpg
# /tmp/PetImages/Cat/cat.2090.jpg /tmp/cats-v-dogs/training/cats/cat.2090.jpg
# /tmp/PetImages/Cat/cat.2414.jpg /tmp/cats-v-dogs/training/cats/cat.2414.jpg
# /tmp/PetImages/Cat/cat.2417.jpg /tmp/cats-v-dogs/training/cats/cat.2417.jpg
# /tmp/PetImages/Cat/cat.685.jpg /tmp/cats-v-dogs/training/cats/cat.685.jpg
# /tmp/PetImages/Cat/cat.409.jpg /tmp/cats-v-dogs/training/cats/cat.409.jpg
# /tmp/PetImages/Cat/cat.2466.jpg /tmp/cats-v-dogs/training/cats/cat.2466.jpg
# /tmp/PetImages/Cat/cat.789.jpg /tmp/cats-v-dogs/training/cats/cat.789.jpg
# /tmp/PetImages/Cat/cat.573.jpg /tmp/cats-v-dogs/training/cats/cat.573.jpg
# /tmp/PetImages/Cat/cat.855.jpg /tmp/cats-v-dogs/training/cats/cat.855.jpg
# /tmp/PetImages/Cat/cat.536.jpg /tmp/cats-v-dogs/training/cats/cat.536.jpg
# /tmp/PetImages/Cat/cat.552.jpg /tmp/cats-v-dogs/training/cats/cat.552.jpg
# /tmp/PetImages/Cat/cat.2490.jpg /tmp/cats-v-dogs/training/cats/cat.2490.jpg
# /tmp/PetImages/Cat/cat.451.jpg /tmp/cats-v-dogs/training/cats/cat.451.jpg
# /tmp/PetImages/Cat/cat.312.jpg /tmp/cats-v-dogs/training/cats/cat.312.jpg
# /tmp/PetImages/Cat/cat.129.jpg /tmp/cats-v-dogs/training/cats/cat.129.jpg
# /tmp/PetImages/Cat/cat.593.jpg /tmp/cats-v-dogs/training/cats/cat.593.jpg
# /tmp/PetImages/Cat/cat.346.jpg /tmp/cats-v-dogs/training/cats/cat.346.jpg
# /tmp/PetImages/Cat/cat.2437.jpg /tmp/cats-v-dogs/training/cats/cat.2437.jpg
# /tmp/PetImages/Cat/cat.2450.jpg /tmp/cats-v-dogs/training/cats/cat.2450.jpg
# /tmp/PetImages/Cat/cat.128.jpg /tmp/cats-v-dogs/training/cats/cat.128.jpg
# /tmp/PetImages/Cat/cat.2016.jpg /tmp/cats-v-dogs/training/cats/cat.2016.jpg
# /tmp/PetImages/Cat/cat.861.jpg /tmp/cats-v-dogs/training/cats/cat.861.jpg
# /tmp/PetImages/Cat/cat.2246.jpg /tmp/cats-v-dogs/training/cats/cat.2246.jpg
# /tmp/PetImages/Cat/cat.268.jpg /tmp/cats-v-dogs/training/cats/cat.268.jpg
# /tmp/PetImages/Cat/cat.5.jpg /tmp/cats-v-dogs/training/cats/cat.5.jpg
# /tmp/PetImages/Cat/cat.23.jpg /tmp/cats-v-dogs/training/cats/cat.23.jpg
# /tmp/PetImages/Cat/cat.2327.jpg /tmp/cats-v-dogs/training/cats/cat.2327.jpg
# /tmp/PetImages/Cat/cat.314.jpg /tmp/cats-v-dogs/training/cats/cat.314.jpg
# /tmp/PetImages/Cat/cat.455.jpg /tmp/cats-v-dogs/training/cats/cat.455.jpg
# /tmp/PetImages/Cat/cat.117.jpg /tmp/cats-v-dogs/training/cats/cat.117.jpg
# /tmp/PetImages/Cat/cat.264.jpg /tmp/cats-v-dogs/training/cats/cat.264.jpg
# /tmp/PetImages/Cat/cat.662.jpg /tmp/cats-v-dogs/training/cats/cat.662.jpg
# /tmp/PetImages/Cat/cat.94.jpg /tmp/cats-v-dogs/training/cats/cat.94.jpg
# /tmp/PetImages/Cat/cat.2371.jpg /tmp/cats-v-dogs/training/cats/cat.2371.jpg
# /tmp/PetImages/Cat/cat.844.jpg /tmp/cats-v-dogs/training/cats/cat.844.jpg
# /tmp/PetImages/Cat/cat.6.jpg /tmp/cats-v-dogs/training/cats/cat.6.jpg
# /tmp/PetImages/Cat/cat.618.jpg /tmp/cats-v-dogs/training/cats/cat.618.jpg
# /tmp/PetImages/Cat/cat.289.jpg /tmp/cats-v-dogs/training/cats/cat.289.jpg
# /tmp/PetImages/Cat/cat.642.jpg /tmp/cats-v-dogs/training/cats/cat.642.jpg
# /tmp/PetImages/Cat/cat.905.jpg /tmp/cats-v-dogs/training/cats/cat.905.jpg
# /tmp/PetImages/Cat/cat.357.jpg /tmp/cats-v-dogs/training/cats/cat.357.jpg
# /tmp/PetImages/Cat/cat.2032.jpg /tmp/cats-v-dogs/training/cats/cat.2032.jpg
# /tmp/PetImages/Cat/cat.266.jpg /tmp/cats-v-dogs/training/cats/cat.266.jpg
# /tmp/PetImages/Cat/cat.347.jpg /tmp/cats-v-dogs/training/cats/cat.347.jpg
# /tmp/PetImages/Cat/cat.2340.jpg /tmp/cats-v-dogs/training/cats/cat.2340.jpg
# /tmp/PetImages/Cat/cat.667.jpg /tmp/cats-v-dogs/training/cats/cat.667.jpg
# /tmp/PetImages/Cat/cat.41.jpg /tmp/cats-v-dogs/training/cats/cat.41.jpg
# /tmp/PetImages/Cat/cat.567.jpg /tmp/cats-v-dogs/training/cats/cat.567.jpg
# /tmp/PetImages/Cat/cat.2170.jpg /tmp/cats-v-dogs/training/cats/cat.2170.jpg
# /tmp/PetImages/Cat/cat.209.jpg /tmp/cats-v-dogs/training/cats/cat.209.jpg
# /tmp/PetImages/Cat/cat.405.jpg /tmp/cats-v-dogs/training/cats/cat.405.jpg
# /tmp/PetImages/Cat/cat.184.jpg /tmp/cats-v-dogs/training/cats/cat.184.jpg
# /tmp/PetImages/Cat/cat.486.jpg /tmp/cats-v-dogs/training/cats/cat.486.jpg
# /tmp/PetImages/Cat/cat.2214.jpg /tmp/cats-v-dogs/training/cats/cat.2214.jpg
# /tmp/PetImages/Cat/cat.854.jpg /tmp/cats-v-dogs/training/cats/cat.854.jpg
# /tmp/PetImages/Cat/cat.2153.jpg /tmp/cats-v-dogs/training/cats/cat.2153.jpg
# /tmp/PetImages/Cat/cat.29.jpg /tmp/cats-v-dogs/training/cats/cat.29.jpg
# /tmp/PetImages/Cat/cat.599.jpg /tmp/cats-v-dogs/training/cats/cat.599.jpg
# /tmp/PetImages/Cat/cat.744.jpg /tmp/cats-v-dogs/training/cats/cat.744.jpg
# /tmp/PetImages/Cat/cat.585.jpg /tmp/cats-v-dogs/training/cats/cat.585.jpg
# /tmp/PetImages/Cat/cat.2374.jpg /tmp/cats-v-dogs/training/cats/cat.2374.jpg
# /tmp/PetImages/Cat/cat.373.jpg /tmp/cats-v-dogs/training/cats/cat.373.jpg
# /tmp/PetImages/Cat/cat.284.jpg /tmp/cats-v-dogs/training/cats/cat.284.jpg
# /tmp/PetImages/Cat/cat.22.jpg /tmp/cats-v-dogs/training/cats/cat.22.jpg
# /tmp/PetImages/Cat/cat.244.jpg /tmp/cats-v-dogs/training/cats/cat.244.jpg
# /tmp/PetImages/Cat/cat.799.jpg /tmp/cats-v-dogs/training/cats/cat.799.jpg
# /tmp/PetImages/Cat/cat.634.jpg /tmp/cats-v-dogs/training/cats/cat.634.jpg
# /tmp/PetImages/Cat/cat.752.jpg /tmp/cats-v-dogs/training/cats/cat.752.jpg
# /tmp/PetImages/Cat/cat.985.jpg /tmp/cats-v-dogs/training/cats/cat.985.jpg
# /tmp/PetImages/Cat/cat.350.jpg /tmp/cats-v-dogs/training/cats/cat.350.jpg
# /tmp/PetImages/Cat/cat.2485.jpg /tmp/cats-v-dogs/training/cats/cat.2485.jpg
# /tmp/PetImages/Cat/cat.2266.jpg /tmp/cats-v-dogs/training/cats/cat.2266.jpg
# /tmp/PetImages/Cat/cat.280.jpg /tmp/cats-v-dogs/training/cats/cat.280.jpg
# /tmp/PetImages/Cat/cat.63.jpg /tmp/cats-v-dogs/training/cats/cat.63.jpg
# /tmp/PetImages/Cat/cat.517.jpg /tmp/cats-v-dogs/training/cats/cat.517.jpg
# /tmp/PetImages/Cat/cat.598.jpg /tmp/cats-v-dogs/training/cats/cat.598.jpg
# /tmp/PetImages/Cat/cat.2052.jpg /tmp/cats-v-dogs/training/cats/cat.2052.jpg
# /tmp/PetImages/Cat/cat.92.jpg /tmp/cats-v-dogs/training/cats/cat.92.jpg
# /tmp/PetImages/Cat/cat.2373.jpg /tmp/cats-v-dogs/training/cats/cat.2373.jpg
# /tmp/PetImages/Cat/cat.2285.jpg /tmp/cats-v-dogs/training/cats/cat.2285.jpg
# /tmp/PetImages/Cat/cat.2048.jpg /tmp/cats-v-dogs/training/cats/cat.2048.jpg
# /tmp/PetImages/Cat/cat.65.jpg /tmp/cats-v-dogs/training/cats/cat.65.jpg
# /tmp/PetImages/Cat/cat.723.jpg /tmp/cats-v-dogs/training/cats/cat.723.jpg
# /tmp/PetImages/Cat/cat.2420.jpg /tmp/cats-v-dogs/training/cats/cat.2420.jpg
# /tmp/PetImages/Cat/cat.2243.jpg /tmp/cats-v-dogs/training/cats/cat.2243.jpg
# /tmp/PetImages/Cat/cat.637.jpg /tmp/cats-v-dogs/training/cats/cat.637.jpg
# /tmp/PetImages/Cat/cat.562.jpg /tmp/cats-v-dogs/training/cats/cat.562.jpg
# /tmp/PetImages/Cat/cat.902.jpg /tmp/cats-v-dogs/training/cats/cat.902.jpg
# /tmp/PetImages/Cat/cat.2063.jpg /tmp/cats-v-dogs/training/cats/cat.2063.jpg
# /tmp/PetImages/Cat/cat.2469.jpg /tmp/cats-v-dogs/training/cats/cat.2469.jpg
# /tmp/PetImages/Cat/cat.2127.jpg /tmp/cats-v-dogs/training/cats/cat.2127.jpg
# /tmp/PetImages/Cat/cat.875.jpg /tmp/cats-v-dogs/training/cats/cat.875.jpg
# /tmp/PetImages/Cat/cat.248.jpg /tmp/cats-v-dogs/training/cats/cat.248.jpg
# /tmp/PetImages/Cat/cat.2494.jpg /tmp/cats-v-dogs/training/cats/cat.2494.jpg
# /tmp/PetImages/Cat/cat.616.jpg /tmp/cats-v-dogs/training/cats/cat.616.jpg
# /tmp/PetImages/Cat/cat.2118.jpg /tmp/cats-v-dogs/training/cats/cat.2118.jpg
# /tmp/PetImages/Cat/cat.2306.jpg /tmp/cats-v-dogs/training/cats/cat.2306.jpg
# /tmp/PetImages/Cat/cat.929.jpg /tmp/cats-v-dogs/training/cats/cat.929.jpg
# /tmp/PetImages/Cat/cat.888.jpg /tmp/cats-v-dogs/training/cats/cat.888.jpg
# /tmp/PetImages/Cat/cat.580.jpg /tmp/cats-v-dogs/training/cats/cat.580.jpg
# /tmp/PetImages/Cat/cat.2192.jpg /tmp/cats-v-dogs/training/cats/cat.2192.jpg
# /tmp/PetImages/Cat/cat.2008.jpg /tmp/cats-v-dogs/training/cats/cat.2008.jpg
# /tmp/PetImages/Cat/cat.2195.jpg /tmp/cats-v-dogs/training/cats/cat.2195.jpg
# /tmp/PetImages/Cat/cat.733.jpg /tmp/cats-v-dogs/training/cats/cat.733.jpg
# /tmp/PetImages/Cat/cat.843.jpg /tmp/cats-v-dogs/training/cats/cat.843.jpg
# /tmp/PetImages/Cat/cat.896.jpg /tmp/cats-v-dogs/training/cats/cat.896.jpg
# /tmp/PetImages/Cat/cat.852.jpg /tmp/cats-v-dogs/training/cats/cat.852.jpg
# /tmp/PetImages/Cat/cat.2350.jpg /tmp/cats-v-dogs/training/cats/cat.2350.jpg
# /tmp/PetImages/Cat/cat.2377.jpg /tmp/cats-v-dogs/training/cats/cat.2377.jpg
# /tmp/PetImages/Cat/cat.617.jpg /tmp/cats-v-dogs/training/cats/cat.617.jpg
# /tmp/PetImages/Cat/cat.214.jpg /tmp/cats-v-dogs/training/cats/cat.214.jpg
# /tmp/PetImages/Cat/cat.989.jpg /tmp/cats-v-dogs/training/cats/cat.989.jpg
# /tmp/PetImages/Cat/cat.2219.jpg /tmp/cats-v-dogs/training/cats/cat.2219.jpg
# /tmp/PetImages/Cat/cat.794.jpg /tmp/cats-v-dogs/training/cats/cat.794.jpg
# /tmp/PetImages/Cat/cat.2472.jpg /tmp/cats-v-dogs/training/cats/cat.2472.jpg
# /tmp/PetImages/Cat/cat.720.jpg /tmp/cats-v-dogs/training/cats/cat.720.jpg
# /tmp/PetImages/Cat/cat.698.jpg /tmp/cats-v-dogs/training/cats/cat.698.jpg
# /tmp/PetImages/Cat/cat.2326.jpg /tmp/cats-v-dogs/training/cats/cat.2326.jpg
# /tmp/PetImages/Cat/cat.456.jpg /tmp/cats-v-dogs/training/cats/cat.456.jpg
# /tmp/PetImages/Cat/cat.829.jpg /tmp/cats-v-dogs/training/cats/cat.829.jpg
# /tmp/PetImages/Cat/cat.36.jpg /tmp/cats-v-dogs/training/cats/cat.36.jpg
# /tmp/PetImages/Cat/cat.743.jpg /tmp/cats-v-dogs/training/cats/cat.743.jpg
# /tmp/PetImages/Cat/cat.858.jpg /tmp/cats-v-dogs/training/cats/cat.858.jpg
# /tmp/PetImages/Cat/cat.2003.jpg /tmp/cats-v-dogs/training/cats/cat.2003.jpg
# /tmp/PetImages/Cat/cat.643.jpg /tmp/cats-v-dogs/training/cats/cat.643.jpg
# /tmp/PetImages/Cat/cat.2360.jpg /tmp/cats-v-dogs/training/cats/cat.2360.jpg
# /tmp/PetImages/Cat/cat.233.jpg /tmp/cats-v-dogs/training/cats/cat.233.jpg
# /tmp/PetImages/Cat/cat.2424.jpg /tmp/cats-v-dogs/training/cats/cat.2424.jpg
# /tmp/PetImages/Cat/cat.787.jpg /tmp/cats-v-dogs/training/cats/cat.787.jpg
# /tmp/PetImages/Cat/cat.901.jpg /tmp/cats-v-dogs/training/cats/cat.901.jpg
# /tmp/PetImages/Cat/cat.404.jpg /tmp/cats-v-dogs/training/cats/cat.404.jpg
# /tmp/PetImages/Cat/cat.123.jpg /tmp/cats-v-dogs/training/cats/cat.123.jpg
# /tmp/PetImages/Cat/cat.355.jpg /tmp/cats-v-dogs/training/cats/cat.355.jpg
# /tmp/PetImages/Cat/cat.2454.jpg /tmp/cats-v-dogs/training/cats/cat.2454.jpg
# /tmp/PetImages/Cat/cat.2242.jpg /tmp/cats-v-dogs/training/cats/cat.2242.jpg
# /tmp/PetImages/Cat/cat.103.jpg /tmp/cats-v-dogs/training/cats/cat.103.jpg
# /tmp/PetImages/Cat/cat.2197.jpg /tmp/cats-v-dogs/training/cats/cat.2197.jpg
# /tmp/PetImages/Cat/cat.804.jpg /tmp/cats-v-dogs/training/cats/cat.804.jpg
# /tmp/PetImages/Cat/cat.30.jpg /tmp/cats-v-dogs/training/cats/cat.30.jpg
# /tmp/PetImages/Cat/cat.576.jpg /tmp/cats-v-dogs/training/cats/cat.576.jpg
# /tmp/PetImages/Cat/cat.994.jpg /tmp/cats-v-dogs/training/cats/cat.994.jpg
# /tmp/PetImages/Cat/cat.2156.jpg /tmp/cats-v-dogs/training/cats/cat.2156.jpg
# /tmp/PetImages/Cat/cat.2054.jpg /tmp/cats-v-dogs/training/cats/cat.2054.jpg
# /tmp/PetImages/Cat/cat.2299.jpg /tmp/cats-v-dogs/training/cats/cat.2299.jpg
# /tmp/PetImages/Cat/cat.2473.jpg /tmp/cats-v-dogs/training/cats/cat.2473.jpg
# /tmp/PetImages/Cat/cat.952.jpg /tmp/cats-v-dogs/training/cats/cat.952.jpg
# /tmp/PetImages/Cat/cat.777.jpg /tmp/cats-v-dogs/training/cats/cat.777.jpg
# /tmp/PetImages/Cat/cat.2006.jpg /tmp/cats-v-dogs/training/cats/cat.2006.jpg
# /tmp/PetImages/Cat/cat.110.jpg /tmp/cats-v-dogs/training/cats/cat.110.jpg
# /tmp/PetImages/Cat/cat.127.jpg /tmp/cats-v-dogs/training/cats/cat.127.jpg
# /tmp/PetImages/Cat/cat.2393.jpg /tmp/cats-v-dogs/training/cats/cat.2393.jpg
# /tmp/PetImages/Cat/cat.693.jpg /tmp/cats-v-dogs/training/cats/cat.693.jpg
# /tmp/PetImages/Cat/cat.918.jpg /tmp/cats-v-dogs/training/cats/cat.918.jpg
# /tmp/PetImages/Cat/cat.866.jpg /tmp/cats-v-dogs/training/cats/cat.866.jpg
# /tmp/PetImages/Cat/cat.2020.jpg /tmp/cats-v-dogs/training/cats/cat.2020.jpg
# /tmp/PetImages/Cat/cat.2385.jpg /tmp/cats-v-dogs/training/cats/cat.2385.jpg
# /tmp/PetImages/Cat/cat.315.jpg /tmp/cats-v-dogs/training/cats/cat.315.jpg
# /tmp/PetImages/Cat/cat.2085.jpg /tmp/cats-v-dogs/training/cats/cat.2085.jpg
# /tmp/PetImages/Cat/cat.827.jpg /tmp/cats-v-dogs/training/cats/cat.827.jpg
# /tmp/PetImages/Cat/cat.393.jpg /tmp/cats-v-dogs/training/cats/cat.393.jpg
# /tmp/PetImages/Cat/cat.363.jpg /tmp/cats-v-dogs/training/cats/cat.363.jpg
# /tmp/PetImages/Cat/cat.2049.jpg /tmp/cats-v-dogs/training/cats/cat.2049.jpg
# /tmp/PetImages/Cat/cat.2073.jpg /tmp/cats-v-dogs/training/cats/cat.2073.jpg
# /tmp/PetImages/Cat/cat.2179.jpg /tmp/cats-v-dogs/training/cats/cat.2179.jpg
# /tmp/PetImages/Cat/cat.759.jpg /tmp/cats-v-dogs/training/cats/cat.759.jpg
# /tmp/PetImages/Cat/cat.434.jpg /tmp/cats-v-dogs/training/cats/cat.434.jpg
# /tmp/PetImages/Cat/cat.520.jpg /tmp/cats-v-dogs/training/cats/cat.520.jpg
# /tmp/PetImages/Cat/cat.596.jpg /tmp/cats-v-dogs/training/cats/cat.596.jpg
# /tmp/PetImages/Cat/cat.2361.jpg /tmp/cats-v-dogs/training/cats/cat.2361.jpg
# /tmp/PetImages/Cat/cat.198.jpg /tmp/cats-v-dogs/training/cats/cat.198.jpg
# /tmp/PetImages/Cat/cat.140.jpg /tmp/cats-v-dogs/training/cats/cat.140.jpg
# /tmp/PetImages/Cat/cat.2349.jpg /tmp/cats-v-dogs/training/cats/cat.2349.jpg
# /tmp/PetImages/Cat/cat.620.jpg /tmp/cats-v-dogs/training/cats/cat.620.jpg
# /tmp/PetImages/Cat/cat.678.jpg /tmp/cats-v-dogs/training/cats/cat.678.jpg
# /tmp/PetImages/Cat/cat.16.jpg /tmp/cats-v-dogs/training/cats/cat.16.jpg
# /tmp/PetImages/Cat/cat.919.jpg /tmp/cats-v-dogs/training/cats/cat.919.jpg
# /tmp/PetImages/Cat/cat.2331.jpg /tmp/cats-v-dogs/training/cats/cat.2331.jpg
# /tmp/PetImages/Cat/cat.798.jpg /tmp/cats-v-dogs/training/cats/cat.798.jpg
# /tmp/PetImages/Cat/cat.187.jpg /tmp/cats-v-dogs/training/cats/cat.187.jpg
# /tmp/PetImages/Cat/cat.651.jpg /tmp/cats-v-dogs/training/cats/cat.651.jpg
# /tmp/PetImages/Cat/cat.2312.jpg /tmp/cats-v-dogs/training/cats/cat.2312.jpg
# /tmp/PetImages/Cat/cat.304.jpg /tmp/cats-v-dogs/training/cats/cat.304.jpg
# /tmp/PetImages/Cat/cat.2263.jpg /tmp/cats-v-dogs/training/cats/cat.2263.jpg
# /tmp/PetImages/Cat/cat.2101.jpg /tmp/cats-v-dogs/training/cats/cat.2101.jpg
# /tmp/PetImages/Cat/cat.52.jpg /tmp/cats-v-dogs/training/cats/cat.52.jpg
# /tmp/PetImages/Cat/cat.97.jpg /tmp/cats-v-dogs/training/cats/cat.97.jpg
# /tmp/PetImages/Cat/cat.2079.jpg /tmp/cats-v-dogs/training/cats/cat.2079.jpg
# /tmp/PetImages/Cat/cat.427.jpg /tmp/cats-v-dogs/training/cats/cat.427.jpg
# /tmp/PetImages/Cat/cat.801.jpg /tmp/cats-v-dogs/training/cats/cat.801.jpg
# /tmp/PetImages/Cat/cat.762.jpg /tmp/cats-v-dogs/training/cats/cat.762.jpg
# /tmp/PetImages/Cat/cat.2144.jpg /tmp/cats-v-dogs/training/cats/cat.2144.jpg
# /tmp/PetImages/Cat/cat.365.jpg /tmp/cats-v-dogs/training/cats/cat.365.jpg
# /tmp/PetImages/Cat/cat.2010.jpg /tmp/cats-v-dogs/training/cats/cat.2010.jpg
# /tmp/PetImages/Cat/cat.2005.jpg /tmp/cats-v-dogs/training/cats/cat.2005.jpg
# /tmp/PetImages/Cat/cat.2453.jpg /tmp/cats-v-dogs/training/cats/cat.2453.jpg
# /tmp/PetImages/Cat/cat.2125.jpg /tmp/cats-v-dogs/training/cats/cat.2125.jpg
# /tmp/PetImages/Cat/cat.300.jpg /tmp/cats-v-dogs/training/cats/cat.300.jpg
# /tmp/PetImages/Cat/cat.221.jpg /tmp/cats-v-dogs/training/cats/cat.221.jpg
# /tmp/PetImages/Cat/cat.2302.jpg /tmp/cats-v-dogs/training/cats/cat.2302.jpg
# /tmp/PetImages/Cat/cat.168.jpg /tmp/cats-v-dogs/training/cats/cat.168.jpg
# /tmp/PetImages/Cat/cat.224.jpg /tmp/cats-v-dogs/training/cats/cat.224.jpg
# /tmp/PetImages/Cat/cat.505.jpg /tmp/cats-v-dogs/training/cats/cat.505.jpg
# /tmp/PetImages/Cat/cat.577.jpg /tmp/cats-v-dogs/training/cats/cat.577.jpg
# /tmp/PetImages/Cat/cat.2448.jpg /tmp/cats-v-dogs/training/cats/cat.2448.jpg
# /tmp/PetImages/Cat/cat.2089.jpg /tmp/cats-v-dogs/training/cats/cat.2089.jpg
# /tmp/PetImages/Cat/cat.389.jpg /tmp/cats-v-dogs/training/cats/cat.389.jpg
# /tmp/PetImages/Cat/cat.768.jpg /tmp/cats-v-dogs/training/cats/cat.768.jpg
# /tmp/PetImages/Cat/cat.367.jpg /tmp/cats-v-dogs/training/cats/cat.367.jpg
# /tmp/PetImages/Cat/cat.240.jpg /tmp/cats-v-dogs/training/cats/cat.240.jpg
# /tmp/PetImages/Cat/cat.407.jpg /tmp/cats-v-dogs/training/cats/cat.407.jpg
# /tmp/PetImages/Cat/cat.2206.jpg /tmp/cats-v-dogs/training/cats/cat.2206.jpg
# /tmp/PetImages/Cat/cat.223.jpg /tmp/cats-v-dogs/training/cats/cat.223.jpg
# /tmp/PetImages/Cat/cat.8.jpg /tmp/cats-v-dogs/training/cats/cat.8.jpg
# /tmp/PetImages/Cat/cat.795.jpg /tmp/cats-v-dogs/training/cats/cat.795.jpg
# /tmp/PetImages/Cat/cat.878.jpg /tmp/cats-v-dogs/training/cats/cat.878.jpg
# ...
# /tmp/PetImages/Dog/dog.2032.jpg /tmp/cats-v-dogs/training/dogs/dog.2032.jpg
# /tmp/PetImages/Dog/dog.885.jpg /tmp/cats-v-dogs/training/dogs/dog.885.jpg
# /tmp/PetImages/Dog/dog.2410.jpg /tmp/cats-v-dogs/training/dogs/dog.2410.jpg
# /tmp/PetImages/Dog/dog.2454.jpg /tmp/cats-v-dogs/training/dogs/dog.2454.jpg
# /tmp/PetImages/Dog/dog.2237.jpg /tmp/cats-v-dogs/training/dogs/dog.2237.jpg
# /tmp/PetImages/Dog/dog.935.jpg /tmp/cats-v-dogs/training/dogs/dog.935.jpg
# /tmp/PetImages/Dog/dog.2064.jpg /tmp/cats-v-dogs/training/dogs/dog.2064.jpg
# /tmp/PetImages/Dog/dog.2441.jpg /tmp/cats-v-dogs/training/dogs/dog.2441.jpg
# /tmp/PetImages/Dog/dog.387.jpg /tmp/cats-v-dogs/training/dogs/dog.387.jpg
# /tmp/PetImages/Dog/dog.2385.jpg /tmp/cats-v-dogs/training/dogs/dog.2385.jpg
# /tmp/PetImages/Dog/dog.128.jpg /tmp/cats-v-dogs/training/dogs/dog.128.jpg
# /tmp/PetImages/Dog/dog.2435.jpg /tmp/cats-v-dogs/training/dogs/dog.2435.jpg
# /tmp/PetImages/Dog/dog.98.jpg /tmp/cats-v-dogs/training/dogs/dog.98.jpg
# /tmp/PetImages/Dog/dog.326.jpg /tmp/cats-v-dogs/training/dogs/dog.326.jpg
# /tmp/PetImages/Dog/dog.893.jpg /tmp/cats-v-dogs/training/dogs/dog.893.jpg
# /tmp/PetImages/Dog/dog.426.jpg /tmp/cats-v-dogs/training/dogs/dog.426.jpg
# /tmp/PetImages/Dog/dog.687.jpg /tmp/cats-v-dogs/training/dogs/dog.687.jpg
# /tmp/PetImages/Dog/dog.2116.jpg /tmp/cats-v-dogs/training/dogs/dog.2116.jpg
# /tmp/PetImages/Dog/dog.830.jpg /tmp/cats-v-dogs/training/dogs/dog.830.jpg
# /tmp/PetImages/Dog/dog.516.jpg /tmp/cats-v-dogs/training/dogs/dog.516.jpg
# /tmp/PetImages/Dog/dog.2202.jpg /tmp/cats-v-dogs/training/dogs/dog.2202.jpg
# /tmp/PetImages/Dog/dog.296.jpg /tmp/cats-v-dogs/training/dogs/dog.296.jpg
# /tmp/PetImages/Dog/dog.138.jpg /tmp/cats-v-dogs/training/dogs/dog.138.jpg
# /tmp/PetImages/Dog/dog.245.jpg /tmp/cats-v-dogs/training/dogs/dog.245.jpg
# /tmp/PetImages/Dog/dog.476.jpg /tmp/cats-v-dogs/training/dogs/dog.476.jpg
# /tmp/PetImages/Dog/dog.294.jpg /tmp/cats-v-dogs/training/dogs/dog.294.jpg
# /tmp/PetImages/Dog/dog.2107.jpg /tmp/cats-v-dogs/training/dogs/dog.2107.jpg
# /tmp/PetImages/Dog/dog.96.jpg /tmp/cats-v-dogs/training/dogs/dog.96.jpg
# /tmp/PetImages/Dog/dog.726.jpg /tmp/cats-v-dogs/training/dogs/dog.726.jpg
# /tmp/PetImages/Dog/dog.589.jpg /tmp/cats-v-dogs/training/dogs/dog.589.jpg
# /tmp/PetImages/Dog/dog.2302.jpg /tmp/cats-v-dogs/training/dogs/dog.2302.jpg
# /tmp/PetImages/Dog/dog.2491.jpg /tmp/cats-v-dogs/training/dogs/dog.2491.jpg
# /tmp/PetImages/Dog/dog.172.jpg /tmp/cats-v-dogs/training/dogs/dog.172.jpg
# /tmp/PetImages/Dog/dog.2053.jpg /tmp/cats-v-dogs/training/dogs/dog.2053.jpg
# /tmp/PetImages/Dog/dog.2043.jpg /tmp/cats-v-dogs/training/dogs/dog.2043.jpg
# /tmp/PetImages/Dog/dog.2272.jpg /tmp/cats-v-dogs/training/dogs/dog.2272.jpg
# /tmp/PetImages/Dog/dog.2080.jpg /tmp/cats-v-dogs/training/dogs/dog.2080.jpg
# /tmp/PetImages/Dog/dog.2358.jpg /tmp/cats-v-dogs/training/dogs/dog.2358.jpg
# /tmp/PetImages/Dog/dog.470.jpg /tmp/cats-v-dogs/training/dogs/dog.470.jpg
# /tmp/PetImages/Dog/dog.584.jpg /tmp/cats-v-dogs/training/dogs/dog.584.jpg
# /tmp/PetImages/Dog/dog.654.jpg /tmp/cats-v-dogs/training/dogs/dog.654.jpg
# /tmp/PetImages/Dog/dog.2143.jpg /tmp/cats-v-dogs/training/dogs/dog.2143.jpg
# /tmp/PetImages/Dog/dog.418.jpg /tmp/cats-v-dogs/training/dogs/dog.418.jpg
# /tmp/PetImages/Dog/dog.2329.jpg /tmp/cats-v-dogs/training/dogs/dog.2329.jpg
# /tmp/PetImages/Dog/dog.805.jpg /tmp/cats-v-dogs/training/dogs/dog.805.jpg
# /tmp/PetImages/Dog/dog.743.jpg /tmp/cats-v-dogs/training/dogs/dog.743.jpg
# /tmp/PetImages/Dog/dog.472.jpg /tmp/cats-v-dogs/training/dogs/dog.472.jpg
# /tmp/PetImages/Dog/dog.473.jpg /tmp/cats-v-dogs/training/dogs/dog.473.jpg
# /tmp/PetImages/Dog/dog.305.jpg /tmp/cats-v-dogs/training/dogs/dog.305.jpg
# /tmp/PetImages/Dog/dog.913.jpg /tmp/cats-v-dogs/training/dogs/dog.913.jpg
# /tmp/PetImages/Dog/dog.2474.jpg /tmp/cats-v-dogs/training/dogs/dog.2474.jpg
# /tmp/PetImages/Dog/dog.436.jpg /tmp/cats-v-dogs/training/dogs/dog.436.jpg
# /tmp/PetImages/Dog/dog.424.jpg /tmp/cats-v-dogs/training/dogs/dog.424.jpg
# /tmp/PetImages/Dog/dog.2230.jpg /tmp/cats-v-dogs/training/dogs/dog.2230.jpg
# /tmp/PetImages/Dog/dog.292.jpg /tmp/cats-v-dogs/training/dogs/dog.292.jpg
# /tmp/PetImages/Dog/dog.191.jpg /tmp/cats-v-dogs/training/dogs/dog.191.jpg
# /tmp/PetImages/Dog/dog.704.jpg /tmp/cats-v-dogs/training/dogs/dog.704.jpg
# /tmp/PetImages/Dog/dog.804.jpg /tmp/cats-v-dogs/training/dogs/dog.804.jpg
# /tmp/PetImages/Dog/dog.926.jpg /tmp/cats-v-dogs/training/dogs/dog.926.jpg
# /tmp/PetImages/Dog/dog.2428.jpg /tmp/cats-v-dogs/training/dogs/dog.2428.jpg
# /tmp/PetImages/Dog/dog.969.jpg /tmp/cats-v-dogs/training/dogs/dog.969.jpg
# /tmp/PetImages/Dog/dog.215.jpg /tmp/cats-v-dogs/training/dogs/dog.215.jpg
# /tmp/PetImages/Dog/dog.540.jpg /tmp/cats-v-dogs/training/dogs/dog.540.jpg
# /tmp/PetImages/Dog/dog.228.jpg /tmp/cats-v-dogs/training/dogs/dog.228.jpg
# /tmp/PetImages/Dog/dog.599.jpg /tmp/cats-v-dogs/training/dogs/dog.599.jpg
# /tmp/PetImages/Dog/dog.375.jpg /tmp/cats-v-dogs/training/dogs/dog.375.jpg
# /tmp/PetImages/Dog/dog.2483.jpg /tmp/cats-v-dogs/training/dogs/dog.2483.jpg
# /tmp/PetImages/Dog/dog.2164.jpg /tmp/cats-v-dogs/training/dogs/dog.2164.jpg
# /tmp/PetImages/Dog/dog.2081.jpg /tmp/cats-v-dogs/training/dogs/dog.2081.jpg
# /tmp/PetImages/Dog/dog.2277.jpg /tmp/cats-v-dogs/training/dogs/dog.2277.jpg
# /tmp/PetImages/Dog/dog.660.jpg /tmp/cats-v-dogs/training/dogs/dog.660.jpg
# /tmp/PetImages/Dog/dog.785.jpg /tmp/cats-v-dogs/training/dogs/dog.785.jpg
# /tmp/PetImages/Dog/dog.939.jpg /tmp/cats-v-dogs/training/dogs/dog.939.jpg
# /tmp/PetImages/Dog/dog.2461.jpg /tmp/cats-v-dogs/training/dogs/dog.2461.jpg
# /tmp/PetImages/Dog/dog.2274.jpg /tmp/cats-v-dogs/training/dogs/dog.2274.jpg
# /tmp/PetImages/Dog/dog.970.jpg /tmp/cats-v-dogs/training/dogs/dog.970.jpg
# /tmp/PetImages/Dog/dog.994.jpg /tmp/cats-v-dogs/training/dogs/dog.994.jpg
# /tmp/PetImages/Dog/dog.208.jpg /tmp/cats-v-dogs/training/dogs/dog.208.jpg
# /tmp/PetImages/Dog/dog.2223.jpg /tmp/cats-v-dogs/training/dogs/dog.2223.jpg
# /tmp/PetImages/Dog/dog.620.jpg /tmp/cats-v-dogs/training/dogs/dog.620.jpg
# /tmp/PetImages/Dog/dog.891.jpg /tmp/cats-v-dogs/training/dogs/dog.891.jpg
# /tmp/PetImages/Dog/dog.2259.jpg /tmp/cats-v-dogs/training/dogs/dog.2259.jpg
# /tmp/PetImages/Dog/dog.2007.jpg /tmp/cats-v-dogs/training/dogs/dog.2007.jpg
# /tmp/PetImages/Dog/dog.2238.jpg /tmp/cats-v-dogs/training/dogs/dog.2238.jpg
# /tmp/PetImages/Dog/dog.869.jpg /tmp/cats-v-dogs/training/dogs/dog.869.jpg
# /tmp/PetImages/Dog/dog.388.jpg /tmp/cats-v-dogs/training/dogs/dog.388.jpg
# /tmp/PetImages/Dog/dog.770.jpg /tmp/cats-v-dogs/training/dogs/dog.770.jpg
# /tmp/PetImages/Dog/dog.681.jpg /tmp/cats-v-dogs/training/dogs/dog.681.jpg
# /tmp/PetImages/Dog/dog.2150.jpg /tmp/cats-v-dogs/training/dogs/dog.2150.jpg
# /tmp/PetImages/Dog/dog.221.jpg /tmp/cats-v-dogs/training/dogs/dog.221.jpg
# /tmp/PetImages/Dog/dog.144.jpg /tmp/cats-v-dogs/training/dogs/dog.144.jpg
# /tmp/PetImages/Dog/dog.310.jpg /tmp/cats-v-dogs/training/dogs/dog.310.jpg
# /tmp/PetImages/Dog/dog.602.jpg /tmp/cats-v-dogs/training/dogs/dog.602.jpg
# /tmp/PetImages/Dog/dog.217.jpg /tmp/cats-v-dogs/training/dogs/dog.217.jpg
# /tmp/PetImages/Dog/dog.733.jpg /tmp/cats-v-dogs/training/dogs/dog.733.jpg
# /tmp/PetImages/Dog/dog.2492.jpg /tmp/cats-v-dogs/training/dogs/dog.2492.jpg
# /tmp/PetImages/Dog/dog.335.jpg /tmp/cats-v-dogs/training/dogs/dog.335.jpg
# /tmp/PetImages/Dog/dog.2333.jpg /tmp/cats-v-dogs/training/dogs/dog.2333.jpg
# /tmp/PetImages/Dog/dog.249.jpg /tmp/cats-v-dogs/training/dogs/dog.249.jpg
# /tmp/PetImages/Dog/dog.532.jpg /tmp/cats-v-dogs/training/dogs/dog.532.jpg
# /tmp/PetImages/Dog/dog.409.jpg /tmp/cats-v-dogs/training/dogs/dog.409.jpg
# /tmp/PetImages/Dog/dog.159.jpg /tmp/cats-v-dogs/training/dogs/dog.159.jpg
# /tmp/PetImages/Dog/dog.2304.jpg /tmp/cats-v-dogs/training/dogs/dog.2304.jpg
# /tmp/PetImages/Dog/dog.2239.jpg /tmp/cats-v-dogs/training/dogs/dog.2239.jpg
# /tmp/PetImages/Dog/dog.325.jpg /tmp/cats-v-dogs/training/dogs/dog.325.jpg
# /tmp/PetImages/Dog/dog.328.jpg /tmp/cats-v-dogs/training/dogs/dog.328.jpg
# /tmp/PetImages/Dog/dog.571.jpg /tmp/cats-v-dogs/training/dogs/dog.571.jpg
# /tmp/PetImages/Dog/dog.2085.jpg /tmp/cats-v-dogs/training/dogs/dog.2085.jpg
# /tmp/PetImages/Dog/dog.647.jpg /tmp/cats-v-dogs/training/dogs/dog.647.jpg
# /tmp/PetImages/Dog/dog.303.jpg /tmp/cats-v-dogs/training/dogs/dog.303.jpg
# /tmp/PetImages/Dog/dog.753.jpg /tmp/cats-v-dogs/training/dogs/dog.753.jpg
# /tmp/PetImages/Dog/dog.213.jpg /tmp/cats-v-dogs/training/dogs/dog.213.jpg
# /tmp/PetImages/Dog/dog.949.jpg /tmp/cats-v-dogs/training/dogs/dog.949.jpg
# /tmp/PetImages/Dog/dog.309.jpg /tmp/cats-v-dogs/training/dogs/dog.309.jpg
# /tmp/PetImages/Dog/dog.487.jpg /tmp/cats-v-dogs/training/dogs/dog.487.jpg
# /tmp/PetImages/Dog/dog.533.jpg /tmp/cats-v-dogs/training/dogs/dog.533.jpg
# /tmp/PetImages/Dog/dog.985.jpg /tmp/cats-v-dogs/training/dogs/dog.985.jpg
# /tmp/PetImages/Dog/dog.742.jpg /tmp/cats-v-dogs/training/dogs/dog.742.jpg
# /tmp/PetImages/Dog/dog.104.jpg /tmp/cats-v-dogs/training/dogs/dog.104.jpg
# /tmp/PetImages/Dog/dog.922.jpg /tmp/cats-v-dogs/training/dogs/dog.922.jpg
# /tmp/PetImages/Dog/dog.2395.jpg /tmp/cats-v-dogs/training/dogs/dog.2395.jpg
# /tmp/PetImages/Dog/dog.860.jpg /tmp/cats-v-dogs/training/dogs/dog.860.jpg
# /tmp/PetImages/Dog/dog.2367.jpg /tmp/cats-v-dogs/training/dogs/dog.2367.jpg
# /tmp/PetImages/Dog/dog.842.jpg /tmp/cats-v-dogs/training/dogs/dog.842.jpg
# /tmp/PetImages/Dog/dog.2297.jpg /tmp/cats-v-dogs/training/dogs/dog.2297.jpg
# /tmp/PetImages/Dog/dog.2327.jpg /tmp/cats-v-dogs/training/dogs/dog.2327.jpg
# /tmp/PetImages/Dog/dog.694.jpg /tmp/cats-v-dogs/training/dogs/dog.694.jpg
# /tmp/PetImages/Dog/dog.520.jpg /tmp/cats-v-dogs/training/dogs/dog.520.jpg
# /tmp/PetImages/Dog/dog.987.jpg /tmp/cats-v-dogs/training/dogs/dog.987.jpg
# /tmp/PetImages/Dog/dog.2493.jpg /tmp/cats-v-dogs/training/dogs/dog.2493.jpg
# /tmp/PetImages/Dog/dog.112.jpg /tmp/cats-v-dogs/training/dogs/dog.112.jpg
# /tmp/PetImages/Dog/dog.2246.jpg /tmp/cats-v-dogs/training/dogs/dog.2246.jpg
# /tmp/PetImages/Dog/dog.835.jpg /tmp/cats-v-dogs/training/dogs/dog.835.jpg
# /tmp/PetImages/Dog/dog.288.jpg /tmp/cats-v-dogs/training/dogs/dog.288.jpg
# /tmp/PetImages/Dog/dog.44.jpg /tmp/cats-v-dogs/training/dogs/dog.44.jpg
# /tmp/PetImages/Dog/dog.360.jpg /tmp/cats-v-dogs/training/dogs/dog.360.jpg
# /tmp/PetImages/Dog/dog.349.jpg /tmp/cats-v-dogs/training/dogs/dog.349.jpg
# /tmp/PetImages/Dog/dog.2389.jpg /tmp/cats-v-dogs/training/dogs/dog.2389.jpg
# /tmp/PetImages/Dog/dog.874.jpg /tmp/cats-v-dogs/training/dogs/dog.874.jpg
# /tmp/PetImages/Dog/dog.461.jpg /tmp/cats-v-dogs/training/dogs/dog.461.jpg
# /tmp/PetImages/Dog/dog.731.jpg /tmp/cats-v-dogs/training/dogs/dog.731.jpg
# /tmp/PetImages/Dog/dog.2152.jpg /tmp/cats-v-dogs/training/dogs/dog.2152.jpg
# /tmp/PetImages/Dog/dog.203.jpg /tmp/cats-v-dogs/training/dogs/dog.203.jpg
# /tmp/PetImages/Dog/dog.2359.jpg /tmp/cats-v-dogs/training/dogs/dog.2359.jpg
# /tmp/PetImages/Dog/dog.936.jpg /tmp/cats-v-dogs/training/dogs/dog.936.jpg
# /tmp/PetImages/Dog/dog.463.jpg /tmp/cats-v-dogs/training/dogs/dog.463.jpg
# /tmp/PetImages/Dog/dog.900.jpg /tmp/cats-v-dogs/training/dogs/dog.900.jpg
# /tmp/PetImages/Dog/dog.763.jpg /tmp/cats-v-dogs/training/dogs/dog.763.jpg
# /tmp/PetImages/Dog/dog.2339.jpg /tmp/cats-v-dogs/training/dogs/dog.2339.jpg
# /tmp/PetImages/Dog/dog.160.jpg /tmp/cats-v-dogs/training/dogs/dog.160.jpg
# /tmp/PetImages/Dog/dog.549.jpg /tmp/cats-v-dogs/training/dogs/dog.549.jpg
# /tmp/PetImages/Dog/dog.2036.jpg /tmp/cats-v-dogs/training/dogs/dog.2036.jpg
# /tmp/PetImages/Dog/dog.100.jpg /tmp/cats-v-dogs/training/dogs/dog.100.jpg
# /tmp/PetImages/Dog/dog.2485.jpg /tmp/cats-v-dogs/training/dogs/dog.2485.jpg
# /tmp/PetImages/Dog/dog.587.jpg /tmp/cats-v-dogs/training/dogs/dog.587.jpg
# /tmp/PetImages/Dog/dog.844.jpg /tmp/cats-v-dogs/training/dogs/dog.844.jpg
# /tmp/PetImages/Dog/dog.2135.jpg /tmp/cats-v-dogs/training/dogs/dog.2135.jpg
# /tmp/PetImages/Dog/dog.68.jpg /tmp/cats-v-dogs/training/dogs/dog.68.jpg
# /tmp/PetImages/Dog/dog.2490.jpg /tmp/cats-v-dogs/training/dogs/dog.2490.jpg
# /tmp/PetImages/Dog/dog.572.jpg /tmp/cats-v-dogs/training/dogs/dog.572.jpg
# /tmp/PetImages/Dog/dog.645.jpg /tmp/cats-v-dogs/training/dogs/dog.645.jpg
# /tmp/PetImages/Dog/dog.2436.jpg /tmp/cats-v-dogs/training/dogs/dog.2436.jpg
# /tmp/PetImages/Dog/dog.176.jpg /tmp/cats-v-dogs/training/dogs/dog.176.jpg
# /tmp/PetImages/Dog/dog.962.jpg /tmp/cats-v-dogs/training/dogs/dog.962.jpg
# /tmp/PetImages/Dog/dog.384.jpg /tmp/cats-v-dogs/training/dogs/dog.384.jpg
# /tmp/PetImages/Dog/dog.990.jpg /tmp/cats-v-dogs/training/dogs/dog.990.jpg
# /tmp/PetImages/Dog/dog.492.jpg /tmp/cats-v-dogs/training/dogs/dog.492.jpg
# /tmp/PetImages/Dog/dog.2041.jpg /tmp/cats-v-dogs/training/dogs/dog.2041.jpg
# /tmp/PetImages/Dog/dog.606.jpg /tmp/cats-v-dogs/training/dogs/dog.606.jpg
# /tmp/PetImages/Dog/dog.2205.jpg /tmp/cats-v-dogs/training/dogs/dog.2205.jpg
# /tmp/PetImages/Dog/dog.2092.jpg /tmp/cats-v-dogs/training/dogs/dog.2092.jpg
# /tmp/PetImages/Dog/dog.372.jpg /tmp/cats-v-dogs/training/dogs/dog.372.jpg
# /tmp/PetImages/Dog/dog.771.jpg /tmp/cats-v-dogs/training/dogs/dog.771.jpg
# /tmp/PetImages/Dog/dog.790.jpg /tmp/cats-v-dogs/training/dogs/dog.790.jpg
# /tmp/PetImages/Dog/dog.151.jpg /tmp/cats-v-dogs/training/dogs/dog.151.jpg
# /tmp/PetImages/Dog/dog.2279.jpg /tmp/cats-v-dogs/training/dogs/dog.2279.jpg
# /tmp/PetImages/Dog/dog.692.jpg /tmp/cats-v-dogs/training/dogs/dog.692.jpg
# /tmp/PetImages/Dog/dog.957.jpg /tmp/cats-v-dogs/training/dogs/dog.957.jpg
# /tmp/PetImages/Dog/dog.523.jpg /tmp/cats-v-dogs/training/dogs/dog.523.jpg
# /tmp/PetImages/Dog/dog.370.jpg /tmp/cats-v-dogs/training/dogs/dog.370.jpg
# /tmp/PetImages/Dog/dog.628.jpg /tmp/cats-v-dogs/training/dogs/dog.628.jpg
# /tmp/PetImages/Dog/dog.47.jpg /tmp/cats-v-dogs/training/dogs/dog.47.jpg
# /tmp/PetImages/Dog/dog.600.jpg /tmp/cats-v-dogs/training/dogs/dog.600.jpg
# /tmp/PetImages/Dog/dog.2265.jpg /tmp/cats-v-dogs/training/dogs/dog.2265.jpg
# /tmp/PetImages/Dog/dog.506.jpg /tmp/cats-v-dogs/training/dogs/dog.506.jpg
# /tmp/PetImages/Dog/dog.632.jpg /tmp/cats-v-dogs/training/dogs/dog.632.jpg
# /tmp/PetImages/Dog/dog.330.jpg /tmp/cats-v-dogs/training/dogs/dog.330.jpg
# /tmp/PetImages/Dog/dog.931.jpg /tmp/cats-v-dogs/training/dogs/dog.931.jpg
# /tmp/PetImages/Dog/dog.609.jpg /tmp/cats-v-dogs/training/dogs/dog.609.jpg
# /tmp/PetImages/Dog/dog.897.jpg /tmp/cats-v-dogs/training/dogs/dog.897.jpg
# /tmp/PetImages/Dog/dog.65.jpg /tmp/cats-v-dogs/training/dogs/dog.65.jpg
# /tmp/PetImages/Dog/dog.2087.jpg /tmp/cats-v-dogs/training/dogs/dog.2087.jpg
# /tmp/PetImages/Dog/dog.675.jpg /tmp/cats-v-dogs/training/dogs/dog.675.jpg
# /tmp/PetImages/Dog/dog.2262.jpg /tmp/cats-v-dogs/training/dogs/dog.2262.jpg
# /tmp/PetImages/Dog/dog.490.jpg /tmp/cats-v-dogs/training/dogs/dog.490.jpg
# /tmp/PetImages/Dog/dog.479.jpg /tmp/cats-v-dogs/training/dogs/dog.479.jpg
# /tmp/PetImages/Dog/dog.701.jpg /tmp/cats-v-dogs/training/dogs/dog.701.jpg
# /tmp/PetImages/Dog/dog.295.jpg /tmp/cats-v-dogs/training/dogs/dog.295.jpg
# /tmp/PetImages/Dog/dog.618.jpg /tmp/cats-v-dogs/training/dogs/dog.618.jpg
# /tmp/PetImages/Dog/dog.695.jpg /tmp/cats-v-dogs/training/dogs/dog.695.jpg
# /tmp/PetImages/Dog/dog.2489.jpg /tmp/cats-v-dogs/training/dogs/dog.2489.jpg
# /tmp/PetImages/Dog/dog.355.jpg /tmp/cats-v-dogs/training/dogs/dog.355.jpg
# /tmp/PetImages/Dog/dog.197.jpg /tmp/cats-v-dogs/training/dogs/dog.197.jpg
# /tmp/PetImages/Dog/dog.2495.jpg /tmp/cats-v-dogs/training/dogs/dog.2495.jpg
# /tmp/PetImages/Dog/dog.720.jpg /tmp/cats-v-dogs/training/dogs/dog.720.jpg
# /tmp/PetImages/Dog/dog.145.jpg /tmp/cats-v-dogs/training/dogs/dog.145.jpg
# /tmp/PetImages/Dog/dog.792.jpg /tmp/cats-v-dogs/training/dogs/dog.792.jpg
# /tmp/PetImages/Dog/dog.665.jpg /tmp/cats-v-dogs/training/dogs/dog.665.jpg
# /tmp/PetImages/Dog/dog.118.jpg /tmp/cats-v-dogs/training/dogs/dog.118.jpg
# /tmp/PetImages/Dog/dog.798.jpg /tmp/cats-v-dogs/training/dogs/dog.798.jpg
# /tmp/PetImages/Dog/dog.0.jpg /tmp/cats-v-dogs/training/dogs/dog.0.jpg
# /tmp/PetImages/Dog/dog.504.jpg /tmp/cats-v-dogs/training/dogs/dog.504.jpg
# /tmp/PetImages/Dog/dog.2251.jpg /tmp/cats-v-dogs/training/dogs/dog.2251.jpg
# /tmp/PetImages/Dog/dog.48.jpg /tmp/cats-v-dogs/training/dogs/dog.48.jpg

# %%
print(len(os.listdir('/tmp/cats-v-dogs/training/cats/')))
print(len(os.listdir('/tmp/cats-v-dogs/training/dogs/')))
print(len(os.listdir('/tmp/cats-v-dogs/testing/cats/')))
print(len(os.listdir('/tmp/cats-v-dogs/testing/dogs/')))

# Expected output:
# 1350
# 1350
# 150
# 150
# Out:
# 1350
# 1350
# 150
# 150

# %%
# DEFINE A KERAS MODEL TO CLASSIFY CATS V DOGS
# USE AT LEAST 3 CONVOLUTION LAYERS
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(150,150,3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer=RMSprop(lr=0.001), loss='binary_crossentropy', metrics=['acc'])

# %% [markdown]
# # NOTE:
#
# In the cell below you **MUST** use a batch size of 10 (`batch_size=10`) for the `train_generator` and the `validation_generator`. Using a batch size greater than 10 will exceed memory limits on the Coursera platform.

# %%
TRAINING_DIR = '/tmp/cats-v-dogs/training'
train_datagen = ImageDataGenerator(rescale=1./255)

# NOTE: YOU MUST USE A BATCH SIZE OF 10 (batch_size=10) FOR THE 
# TRAIN GENERATOR.
train_generator = train_datagen.flow_from_directory(
    TRAINING_DIR,
    target_size=(150, 150),
    batch_size=10,
    class_mode='binary')

VALIDATION_DIR = '/tmp/cats-v-dogs/testing'
validation_datagen = ImageDataGenerator(rescale=1./255)

# NOTE: YOU MUST USE A BACTH SIZE OF 10 (batch_size=10) FOR THE 
# VALIDATION GENERATOR.
validation_generator = validation_datagen.flow_from_directory(
    VALIDATION_DIR,
    target_size=(150, 150),
    batch_size=10,
    class_mode='binary')



# Expected Output:
# Found 2700 images belonging to 2 classes.
# Found 300 images belonging to 2 classes.
# Out:
# Found 2700 images belonging to 2 classes.
# Found 300 images belonging to 2 classes.

# %%
history = model.fit_generator(train_generator,
                              epochs=3,
                              verbose=1,
                              validation_data=validation_generator)
# Out:
# Epoch 1/3
# 270/270 [==============================] - 36s 132ms/step - loss: 0.7792 - acc: 0.5659 - val_loss: 0.5920 - val_acc: 0.7033
# Epoch 2/3
# 270/270 [==============================] - 31s 117ms/step - loss: 0.6265 - acc: 0.6630 - val_loss: 0.5521 - val_acc: 0.7100
# Epoch 3/3
# 270/270 [==============================] - 33s 124ms/step - loss: 0.5625 - acc: 0.7248 - val_loss: 0.5426 - val_acc: 0.7300

# %%
# PLOT LOSS AND ACCURACY
# %matplotlib inline

import matplotlib.image  as mpimg
import matplotlib.pyplot as plt

#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc=history.history['acc']
val_acc=history.history['val_acc']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot(epochs, acc, 'r', "Training Accuracy")
plt.plot(epochs, val_acc, 'b', "Validation Accuracy")
plt.title('Training and validation accuracy')
plt.figure()

#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot(epochs, loss, 'r', "Training Loss")
plt.plot(epochs, val_loss, 'b', "Validation Loss")


plt.title('Training and validation loss')

# Desired output. Charts with training and validation metrics. No crash :)
# Out:
# Text(0.5, 1.0, 'Training and validation loss')

# %% [markdown]
# # Submission Instructions

# %%
# Now click the 'Submit Assignment' button above.

# %% [markdown]
# # When you're done or would like to take a break, please run the two cells below to save your work and close the Notebook. This will free up resources for your fellow learners.

# %%
# %%javascript
# <!-- Save the notebook -->
# IPython.notebook.save_checkpoint();

# %%
# %%javascript
# IPython.notebook.session.delete();
# window.onbeforeunload = null
# setTimeout(function() { window.close(); }, 1000);
